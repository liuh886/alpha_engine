# %% [markdown]
# # QQQ/TQQQ downside-volatility veto v4.2
# Independent test of realized QQQ downside volatility beyond frozen VIX/VXN rules.

# %%
from pathlib import Path
import yaml
from src.research.etf_rotation_experiment import fetch_adjusted_daily_bars
from src.research.downside_volatility_veto_experiment import run_downside_volatility_veto_comparison

# %%
contract_path = Path('../configs/research_paradigms/qqq_tqqq_downside_vol_veto_v4_2.yaml')
contract = yaml.safe_load(contract_path.read_text(encoding='utf-8'))
base_path = Path('..') / contract['base_contract']
contract['resolved_base_contract'] = yaml.safe_load(base_path.read_text(encoding='utf-8'))
bars, coverage = fetch_adjusted_daily_bars(symbols=['QQQ', 'TQQQ', '^VIX', '^VXN'], start=contract['resolved_base_contract']['data']['start_date'])
metrics, results, prepared, diagnostics, tables = run_downside_volatility_veto_comparison(bars, contract)
metrics

# %%
diagnostics['stress_overlap']

# %%
tables['transition_events']

# %%
tables['chronological_periods']
