# %% [markdown]
# # Canonical 10D Signal Discovery
#
# This notebook is a reader for the same report produced by `scripts/generate_10d_signal_discovery.py` and release evidence. Holding and rebalance are fixed at 10 trading sessions.
#
# Data contracts: training labels may be processed for fitting; `raw_forward_return` is the unprocessed future 10D stock return; benchmark excess is stock raw return minus same-date QQQ raw return; winner/rank labels are training targets only; all economic metrics consume raw future returns.

# %%
import json, sys
from pathlib import Path
ROOT = Path.cwd()
while not (ROOT / 'src').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from scripts.generate_10d_signal_discovery import RAW_RETURN_EXPRESSION, MOMENTUM_EXPRESSION
from src.research.signal_discovery import run_signal_discovery_comparison
REPORT = ROOT / 'artifacts/evidence/10d_signal_discovery/us_signal_discovery_report.json'

# %% [markdown]
# Generate or refresh the evidence from the repository root:
#
# ```powershell
# uv run python scripts/generate_10d_signal_discovery.py --predictions <out-of-sample-predictions.csv> --provider-uri data/watchlist
# ```
#
# The CLI and release candidate generator both delegate metrics, direction diagnostics, promotion classification, and report serialization to `run_signal_discovery_comparison`.

# %%
report = json.loads(REPORT.read_text(encoding='utf-8'))
assert report['label_horizon'] == report['rebalance_days'] == 10
report['summary'], report['candidates']
